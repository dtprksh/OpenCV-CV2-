# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1=cv2.imread('ansuj.jpg')
img2=cv2.imread('km.jpg')

# %%
img1.shape
# Out:
# (4160, 3120, 3)

# %%
img2.shape
# Out:
# (4160, 3120, 3)

# %%
img=cv2.add(img1,img2)
img[:,:,2]=0
plt.imshow(img)
plt.xticks([]),plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
plt.imshow(img1+img2)

# %%
img2[:,:,0]=0
plt.imshow(img2)

# %%
face=img2[200:2600,1300:2500]
img2[200:2600,100:1300]=face
plt.imshow(img2)

# %%
plt.imshow(img1)

# %%
img1[600:3000,1920:3120]=face
plt.imshow(img1)

# %%
img3=cv2.imread('shyam.jpg',-1)
plt.imshow(img3)

# %%
dis=cv2.addWeighted(img1,0.4,img3,0.6,0)
plt.imshow(dis)

# %%
logo=cv2.imread('fool1.jpeg')
rows,cols,channels=logo.shape
roi=img3[0:rows,0:cols]
img2gray=cv2.cvtColor(logo,cv2.COLOR_BGR2GRAY)
ret,mask=cv2.threshold(img2gray,100,255,cv2.THRESH_BINARY)
mask_inv=cv2.bitwise_not(mask)
#img3_bg=cv2.bitwise_and(roi,roi,mask=mask_inv)
img3_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)
logo_fg=cv2.bitwise_and(logo,logo,mask=mask)
dst=cv2.add(img3_bg,logo_fg)
img3[0:rows,0:cols]=dst
plt.imshow(img3)

# %%
img=cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
