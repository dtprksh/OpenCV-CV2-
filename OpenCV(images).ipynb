# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('Brokerage_Reciept.jpg',0)
plt.imshow(img,cmap='gray',interpolation='bicubic')
plt.xticks([]),plt.yticks([])
plt.show()

# %%
cv2.namedWindow('brokerage', cv2.WINDOW_NORMAL)
cv2.imshow('brokerage',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
